# %%
Q1. What is Bayes' theorem?
ans:
Bayes' theorem is a mathematical formula that describes the probability of an event based on prior knowledge or information. It is named after the 18th-century
British statistician Thomas Bayes, who formulated the theorem.

The theorem states that the probability of an event A occurring given that event B has occurred is equal to the probability of event B occurring given that
event A has occurred, multiplied by the probability of event A occurring, divided by the probability of event B occurring. This can be expressed mathematically
as:

P(A|B) = P(B|A) * P(A) / P(B)

where:

P(A|B) is the probability of event A occurring given that event B has occurred (known as the posterior probability).
P(B|A) is the probability of event B occurring given that event A has occurred (known as the likelihood).
P(A) is the prior probability of event A occurring.
P(B) is the prior probability of event B occurring.
Bayes' theorem is widely used in fields such as statistics, machine learning, and artificial intelligence to make predictions and decisions based 
on available data and prior knowledge.

# %%
Q2. What is the formula for Bayes' theorem?
ans:
The formula for Bayes' theorem is:

P(A|B) = P(B|A) * P(A) / P(B)

where:

P(A|B) is the probability of event A occurring given that event B has occurred (known as the posterior probability).
P(B|A) is the probability of event B occurring given that event A has occurred (known as the likelihood).
P(A) is the prior probability of event A occurring.
P(B) is the prior probability of event B occurring.
This formula describes how to update the probability of event A occurring (the posterior probability) based on new information about event B.

# %%
Q3. How is Bayes theorem used in practice?
ans:
Bayes theorem is used in practice in a variety of fields, including statistics, machine learning, artificial intelligence, and decision-making. Some common 
applications of Bayes' theorem include:

Medical diagnosis: Bayes theorem can be used to calculate the probability of a patient having a certain disease given their symptoms, medical history, and
other factors. By using Bayes theorem, doctors can make more accurate diagnoses and choose the most appropriate treatments.

Spam filtering: Bayes theorem can be used to classify emails as spam or not spam. By analyzing the text of an email and calculating the probability of it 
being spam or not, a spam filter can automatically move the email to the appropriate folder.

Fraud detection: Bayes theorem can be used to identify fraudulent transactions in banking and credit card systems. By analyzing transaction patterns and 
calculating the probability of a transaction being fraudulent, banks can automatically flag suspicious transactions for further investigation.

Recommender systems: Bayes theorem can be used to make personalized recommendations to users based on their past behavior and preferences. By calculating 
the probability of a user liking a certain product or service, a recommender system can suggest items that the user is likely to be interested in.

Decision-making: Bayes theorem can be used to make decisions under uncertainty by taking into account prior probabilities and new information. By updating 
prior probabilities with new data, decision-makers can make more informed choices and reduce the risk of errors or biases.

Overall, Bayes theorem is a powerful tool for making predictions and decisions based on available data and prior knowledge, and has many practical
applications across a wide range of fields.

# %%
Q4. What is the relationship between Bayes theorem and conditional probability?
ans:
Bayes theorem and conditional probability are closely related concepts. In fact, Bayes theorem can be derived from conditional probability.

Conditional probability is the probability of an event A occurring given that event B has occurred, and is written as P(A|B). It is calculated as the 
probability of both events A and B occurring, divided by the probability of event B occurring:

P(A|B) = P(A and B) / P(B)

Bayes theorem uses conditional probability to update the probability of an event based on new information or evidence. Specifically, it calculates the 
probability of event A occurring given that event B has occurred, as a function of the prior probability of A (P(A)), the likelihood of B given A (P(B|A)), 
and the prior probability of B (P(B)):

P(A|B) = P(B|A) * P(A) / P(B)

In this formula, P(B|A) is the conditional probability of B given A, which represents the likelihood of observing event B given that event A has occurred.

Thus, Bayes theorem can be seen as a way of updating prior beliefs or probabilities based on new evidence or observations, using conditional probability as a
building block.

# %%
Q5. How do you choose which type of Naive Bayes classifier to use for any given problem?
ans:
There are three main types of Naive Bayes classifiers: Gaussian Naive Bayes, Multinomial Naive Bayes, and Bernoulli Naive Bayes. The choice of which type of 
classifier to use depends on the nature of the problem and the characteristics of the data.

Here are some general guidelines for choosing the appropriate Naive Bayes classifier:

Gaussian Naive Bayes: This classifier is appropriate for continuous or numerical data that follows a normal distribution. It assumes that the features are 
independent and normally distributed, and can be used for regression or classification tasks.

Multinomial Naive Bayes: This classifier is appropriate for discrete or count data, such as word frequencies in text data. It assumes that the features are
independent and follow a multinomial distribution, and can be used for classification tasks.

Bernoulli Naive Bayes: This classifier is also appropriate for discrete or binary data, such as the presence or absence of a feature. It assumes that the 
features are independent and follow a Bernoulli distribution, and can be used for classification tasks.

In general, the choice of Naive Bayes classifier should be based on the type of data and the assumptions that best fit the problem. It is also important to 
consider the trade-off between model complexity and accuracy, and to evaluate the performance of different classifiers using appropriate metrics such as 
accuracy, precision, recall, and F1-score.

# %%
Q6. You have a dataset with two features, X1 and X2, and two possible classes, A and B. You want to use Naive
Bayes to classify a new instance with features X1 = 3 and X2 = 4. The following table shows the frequency of
each feature value for each class:
Class X1=1 X1=2 X1=3 X2=1 X2=2 X2=3 X2=4
A      3    3    4    4    3    3     3
B      2    2    1    2    2    2     3
Assuming equal prior probabilities for each class, which class would Naive Bayes predict the new instance
to belong to?
ans:
To classify the new instance with features X1=3 and X2=4, we can use Naive Bayes to calculate the posterior probability of the instance belonging to each class
, given its feature values. Assuming equal prior probabilities for each class, we have:

P(A|X1=3, X2=4) = P(X1=3|A) * P(X2=4|A) * P(A) / P(X1=3, X2=4)
P(B|X1=3, X2=4) = P(X1=3|B) * P(X2=4|B) * P(B) / P(X1=3, X2=4)

P(X1=3|A)=4/10
P(X1=3|B)=1/7
P(X2=4|A)=3/10
P(X2=4|B)=3/7

To calculate the denominator P(X1=3, X2=4), we can use the total frequencies of X1=3 and X2=4 across both classes:

P(X1=3, X2=4) = P(X1=3, X2=4|A) * P(A) + P(X1=3, X2=4|B) * P(B)
= (4/10 * 3/10 * 0.5) + (1/7 * 3/7 * 0.5)
= 0.049

Substituting these values into the posterior probabilities, we get:

P(A|X1=3, X2=4) = (4/10 * 3/10 * 0.5) / 0.049 = 0.387
P(B|X1=3, X2=4) = (1/7 * 3/7 * 0.5) / 0.049 = 0.613

Therefore, Naive Bayes would predict the new instance to belong to class B, since it has a higher posterior probability of 0.613 compared to class A's 
probability of 0.387.
